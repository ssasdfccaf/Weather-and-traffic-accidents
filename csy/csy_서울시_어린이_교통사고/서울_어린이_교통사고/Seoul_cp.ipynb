# %%
df
# Out:
#            종로구  강남구
# 지역구        거주자  사고수
# 종로구    145,714   28
# 중구     121,926   19
# 용산구    218,691   36
# 성동구    295,428   38
# 광진구    346,032   72
# 동대문구   339,364   60
# 중랑구    391,196   95
# 성북구    434,848   82
# 강북구    308,385   59
# 도봉구    329,039   54
# 노원구    527,045   92
# 은평구    471,936   85
# 서대문구   302,628   44
# 마포구    366,365   57
# 양천구    452,784  114
# 강서구    584,804   99
# 구로구    401,965   94
# 금천구    228,716   43
# 영등포구   360,215   88
# 동작구    390,198   66
# 관악구    492,126   58
# 서초구    422,317   80
# 강남구    532,911  115
# 송파구    666,686  140
# 강동구    429,637   87

# %%
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False  


# CSV 파일 읽어오기
data = pd.read_csv('../서울예측DB(수정).csv', encoding='cp949')

data.head()
# Out:
#     지역구     인구수  어린이인구수  어린이사고수  차량등록대수  어린이공원개수  어린이집수  유치원수  유아원수  초등학교수  \
# 0  종로구   145714  145714      28   50052       24    116    17   133     13
# 1   중구   121926  121926      19   51736       16     94    14   108     12
# 2  용산구   218691  218691      36   76521       23    179    17   196     15
# 3  성동구   295428  295428      38  106263       32    275    31   306     21
# 4  광진구   346032  346032      72   99299       35    294    36   330     21
#
#    어린이보호구역CCTV수  어린이보호구역개수   예측어린이사고수
# 0            45         48   69981.19
# 1            76         43   63579.55
# 2           235         37   78811.54
# 3           490         52   99051.64
# 4           625         74  100554.83

# %% [markdown]
# 어린이 보호구역 CCTV 수

# %%
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False  

# CSV 파일 읽어오기
data = pd.read_csv('../서울예측DB(수정).csv', encoding='cp949')

# Seaborn의 pairplot 함수 - 데이터셋에서 두 변수 간의 산점도 행렬(pair plot) 생성 ->  지역별로 어린이 사고 수 대비 어린이보호구역 CCTV 수'의 상관관계 분석
pp = sns.pairplot(data, vars=['어린이사고수', '어린이보호구역CCTV수'], hue='지역구', palette='Set2')

pp.fig.suptitle("어린이 사고 수 대비 어린이보호구역 CCTV 수", y=1.11, fontsize=12.5)  

plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
districts = ["종로구", "중구", "용산구", "성동구", "광진구", "동대문구", "중랑구", "성북구", "강북구", "도봉구", "노원구",
             "은평구", "서대문구", "마포구", "양천구", "강서구", "구로구", "금천구", "영등포구", "동작구", "관악구", "서초구",
             "강남구", "송파구", "강동구"]

predicted_accidents = [28, 19, 36, 38, 72, 60, 95, 82, 59, 54, 92, 85, 44, 57, 114, 99, 94, 43, 88, 66, 58, 80, 115, 140, 87]

# 라인 그래프 그리기
plt.figure(figsize=(12, 6))
plt.plot(districts, predicted_accidents, marker='o', color='orange', linestyle='-', linewidth=2, markersize=8)
plt.title('Predicted Child Accidents by District (Line Chart)')
plt.xlabel('District')
plt.ylabel('Predicted Accidents')
plt.xticks(rotation=45, ha='right')
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

districts = ["종로구", "중구", "용산구", "성동구", "광진구", "동대문구", "중랑구", "성북구", "강북구", "도봉구", "노원구",
             "은평구", "서대문구", "마포구", "양천구", "강서구", "구로구", "금천구", "영등포구", "동작구", "관악구", "서초구",
             "강남구", "송파구", "강동구"]

predicted_accidents = [28, 19, 36, 38, 72, 60, 95, 82, 59, 54, 92, 85, 44, 57, 114, 99, 94, 43, 88, 66, 58, 80, 115, 140, 87]

# 수평 막대 그래프 그리기
fig, ax = plt.subplots(figsize=(10, 8))
y_pos = np.arange(len(districts))
ax.barh(y_pos, predicted_accidents, color='green')
ax.set_yticks(y_pos)
ax.set_yticklabels(districts)
ax.invert_yaxis()  # 상위 구가 상단에 오도록 순서 뒤집기
ax.set_xlabel('Predicted Accidents')
ax.set_title('Predicted Child Accidents by District (Horizontal Bar)')

plt.show()

# %%
from matplotlib import rc  
import seaborn as sns
  
rc('font', family='AppleGothic') 			
plt.rcParams['axes.unicode_minus'] = False  

# 바이올린 플롯
plt.figure(figsize=(14, 8))
sns.violinplot(x='지역구', y='어린이사고수', data=df, inner='quartile', palette='Pastel1')
sns.swarmplot(x='지역구', y='어린이사고수', data=df, color='black', size=3)
plt.title('어린이 사고 수 대비 어린이보호구역 CCTV 수')
plt.xticks(rotation=45, ha='right')  # x축 레이블 회전
plt.show()
# Out:
# /var/folders/jw/ndvxfvvs0j15nzphpj_wq_sr0000gn/T/ipykernel_1845/1027629624.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='지역구', y='어린이사고수', data=df, inner='quartile', palette='Pastel1')

# %% [markdown]
# # 서울 지역구별 비교

# %% [markdown]
# 어린이 사고 수 비교

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rc  
rc('font', family='AppleGothic') 			
plt.rcParams['axes.unicode_minus'] = False  

# Horizontal Bar Plot

data = {
    '지역구': ['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
    '거주자': [145714, 121926, 218691, 295428, 346032, 339364, 391196, 434848, 308385, 329039, 527045, 471936, 302628, 366365, 452784, 584804, 401965, 228716, 360215, 390198, 492126, 422317, 532911, 666686, 429637],
    '사고수': [28, 19, 36, 38, 72, 60, 95, 82, 59, 54, 92, 85, 44, 57, 114, 99, 94, 43, 88, 66, 58, 80, 115, 140, 87]
}

df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(12, 6))
bars = plt.barh(df['지역구'], df['사고수'], color=plt.cm.viridis(df['사고수'] / max(df['사고수'])))

# data labels 추가
for bar, label in zip(bars, df['거주자']):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, f'{label:,}', va='center')

# 라벨과 제목 설정
plt.title('어린이 교통사고 수에 따른 지역구 비교')
plt.xlabel('어린이 교통사고 수')
plt.ylabel('지역구')
plt.grid(axis='x')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    '지역구': ['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'],
    '어린이사고수': [28, 19, 36, 38, 72, 60, 95, 82, 59, 54, 92, 85, 44, 57, 114, 99, 94, 43, 88, 66, 58, 80, 115, 140, 87]
}

df = pd.DataFrame(data)

# Violin Plot 그래프 설정 
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

# 지역구별 어린이 사고 수
plt.figure(figsize=(10, 6))
plt.violinplot(dataset=df['어린이사고수'], showmedians=True, vert=False)
plt.yticks([1], ['어린이 사고 수'])
plt.title('지역구별 어린이 사고 수')

plt.show()

# %% [markdown]
# # 종로구 vs 강남구

# %%
from matplotlib import rc 
import seaborn as sns
  
rc('font', family='AppleGothic') 			
plt.rcParams['axes.unicode_minus'] = False  

# 서울시 강남구 픽 -> 비교
data = {'종로구': [28, 48],
        '강남구': [115, 1157]}

# 데이터프레임 생성
df_boxplot = pd.DataFrame(data)

# 상자수염 
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_boxplot, palette=['skyblue', 'lightcoral'])
plt.title('종로구 vs 강남구 어린이 사고 수 비교')
plt.ylabel('어린이 사고 수')
plt.show()

# %%
# CSV 파일 경로
PATH = '../지역구별 인구 수 대비 어린이 사고수.csv'

# CSV 파일 읽기
# df = pd.read_csv('/지역구별 인구 수 대비 어린이 사고수.csv')
df = pd.read_csv(PATH, header=None, names=['종로구', '강남구'], encoding='cp949')

# 데이터프레임의 처음 7행 출력
print(df.head(7))
# print(df["종로구","강남구"])
# Out:
#            종로구  강남구
# 지역구        거주자  사고수
# 종로구    145,714   28
# 중구     121,926   19
# 용산구    218,691   36
# 성동구    295,428   38
# 광진구    346,032   72
# 동대문구   339,364   60

# %%
# 종로구 vs 강남구
data = {'종로구': [28, 48],
        '강남구': [115, 1157]}

df_violin = pd.DataFrame(data)

# 바이올린 플롯 그리기
plt.figure(figsize=(10, 6))
sns.violinplot(data=df_violin, palette=['skyblue', 'lightcoral'])
plt.title('종로구 vs 강남구 어린이 사고 수 비교 (종로구 19.6% < 강남구 80.4%)')
plt.ylabel('어린이 사고 수')
plt.show()
