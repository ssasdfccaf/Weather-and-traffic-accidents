# %% [markdown]
# # 예시

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['1', '2', '3', '4']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['silver', 'gold', 'whitesmoke', 'lightgray']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['1', '2', '3', '4']
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['silver', 'gold', 'whitesmoke', 'lightgray']

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True, colors=colors)
plt.show()

# %%
# 1=양천구 ,2=강남구, 3=송파구

import matplotlib.pyplot as plt

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = [1, 2, 3]
y = [4, 5, 6]

fig, ax = plt.subplots()

bars = ax.bar(x, y, color='lightgray', edgecolor='black')
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %%
# 예측1

# 1=은평구 ,2=강남구, 3=양천구

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

fig, ax = plt.subplots()

# 진한 노란색
bars = ax.bar(x, y, color='#FFD700', edgecolor='black')  
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %%
# 예측1

# 1=은평구 ,2=강남구, 3=양천구

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

fig, ax = plt.subplots()

# 진한 노란색
bars = ax.bar(x, y, color='#FFD700', edgecolor='black')  
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %%
# 예측2 

# 1=은평구 ,2=강남구, 3=양천구

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

fig, ax = plt.subplots()

# 진한 노란색
bars = ax.bar(x, y, color='#FFD700', edgecolor='black')  
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = [1, 2, 3]
y = [4, 5, 6]

fig, ax = plt.subplots()

bars = ax.bar(x, y, color='yellow', edgecolor='black')  
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %%
# 예측3

# 1 중구 2 서대문구 3 동작구

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

fig, ax = plt.subplots()

# 연한 노란색으로 변경
bars = ax.bar(x, y, color='#FFFF99', edgecolor='black')  # '#FFFF99'은 연한 노란색의 Hex 코드

bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

fig, ax = plt.subplots()

# 진한 노란색으로 변경
bars = ax.bar(x, y, color='#FFD700', edgecolor='black')  # '#FFD700' 진한 노란색의 Hex 코드

bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('default')
plt.rcParams['figure.figsize'] = (6, 5)
plt.rcParams['font.size'] = 12

x = [1, 2, 3]
y = [1, 2, 3]

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

ax1.bar(x, y, color='aquamarine', edgecolor='black', hatch='/')
ax2.bar(x, y, color='salmon', edgecolor='black', hatch='\\')
ax3.bar(x, y, color='navajowhite', edgecolor='black', hatch='+')
ax4.bar(x, y, color='lightskyblue', edgecolor='black', hatch='*')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 종로구 vs 강남구

# %%
from matplotlib import rc  
rc('font', family='AppleGothic') 			
plt.rcParams['axes.unicode_minus'] = False  

# ?��?��?�� 강남�? ?�� -> 비교
data = {'종로�?': [28, 48],
        '강남�?': [115, 1157]}

# ?��?��?��?��?��?�� ?��?��
df_boxplot = pd.DataFrame(data)

# ?��?��?��?�� 
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_boxplot, palette=['skyblue', 'lightcoral'])
plt.title('종로�? vs 강남�? ?��린이 ?���? ?�� 비교')
plt.ylabel('?��린이 ?���? ?��')
plt.show()

# %%
# 종로�? vs 강남�?
data = {'종로�?': [28, 48],
        '강남�?': [115, 1157]}

df_violin = pd.DataFrame(data)

# 바이?���? ?���? 그리�?
plt.figure(figsize=(10, 6))
sns.violinplot(data=df_violin, palette=['skyblue', 'lightcoral'])
plt.title('종로�? vs 강남�? ?��린이 ?���? ?�� 비교 (종로�? 19.6% < 강남�? 80.4%)')
plt.ylabel('?��린이 ?���? ?��')
plt.show()

# %%
# Radar Chart 
# ?��린이 ?���? ?�� 비교 ( 종로�? vs 강남�? ) - �??�� 간의 ?��????��?�� ?���?, ?��?�� 강조

import numpy as np

categories = ['?��린이 ?���? ?��', '?��린이보호구역 CCTV ?��', '?��린이 공원 개수', '?��린이 �? ?��', '?��치원 ?��']
values_jongro = [28, 48, 24, 116, 17]
values_gangnam = [115, 1157, 62, 359, 40]

# �? 번째 �? 추�?? - ?��?�� ?��?��
categories += [categories[0]]
values_jongro += [values_jongro[0]]
values_gangnam += [values_gangnam[0]]

# �? �??��?�� 각도 계산
angles = np.linspace(0, 2 * np.pi, len(categories), endpoint=False)

# 그래?�� 그리�?
plt.figure(figsize=(8, 8))
plt.polar(angles, values_jongro, marker='o', linestyle='solid', linewidth=2, color='skyblue', fill=True, label='종로�?')
plt.polar(angles, values_gangnam, marker='o', linestyle='solid', linewidth=2, color='lightcoral', fill=True, label='강남�?')

# �? �??��?�� ?���? ?���?
plt.xticks(angles[:-1], categories, color='grey', size=12)

# 그래?�� ?���?
plt.title('종로�? vs 강남�?', size=18, color='blue', y=1.1)

# 범�?? 추�??
plt.legend(loc='upper right')

# 그래?�� ?��?��
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/sophie/Desktop/230125_11AM/Weather-and-traffic-accidents/?��?��/?��?��?�� ?��린이 교통?���?/csy/Seoul_predict.ipynb ??? 6 line 2
#      <a href='vscode-notebook-cell:/Users/sophie/Desktop/230125_11AM/Weather-and-traffic-accidents/%EB%8F%99%EC%98%A5/%EC%84%9C%EC%9A%B8%EC%8B%9C%20%EC%96%B4%EB%A6%B0%EC%9D%B4%20%EA%B5%90%ED%86%B5%EC%82%AC%EA%B3%A0/csy/Seoul_predict.ipynb#X13sZmlsZQ%3D%3D?line=17'>18</a> # 그래?�� 그리�?
#      <a href='vscode-notebook-cell:/Users/sophie/Desktop/230125_11AM/Weather-and-traffic-accidents/%EB%8F%99%EC%98%A5/%EC%84%9C%EC%9A%B8%EC%8B%9C%20%EC%96%B4%EB%A6%B0%EC%9D%B4%20%EA%B5%90%ED%86%B5%EC%82%AC%EA%B3%A0/csy/Seoul_predict.ipynb#X13sZmlsZQ%3D%3D?line=18'>19</a> plt.figure(figsize=(8, 8))
# ...

# %% [markdown]
# # 막대 그래프 X

# %%
from matplotlib import rc  
rc('font', family='AppleGothic') 			
plt.rcParams['axes.unicode_minus'] = False  

import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import rc  
rc('font', family='AppleGothic') 			
plt.rcParams['axes.unicode_minus'] = False  

# 주어�? ?��?��?��
data = {
    '�??���?': ['종로�?', '중구', '?��?���?', '?��?���?', '광진�?', '?��???문구', '중랑�?', '?��북구', '강북�?', '?��봉구', '?��?���?', '????���?', '?��???문구', '마포�?', '?��천구', '강서�?', '구로�?', '금천�?', '?��?��?���?', '?��?���?', '�??���?', '?��초구', '강남�?', '?��?���?', '강동�?'],
    '?��린이?��고수': [28, 19, 36, 38, 72, 60, 95, 82, 59, 54, 92, 85, 44, 57, 114, 99, 94, 43, 88, 66, 58, 80, 115, 140, 87]
}

# ?��?��?��?��?��?�� ?��?��
df = pd.DataFrame(data)

# 그래?�� ?��?��
plt.style.use('default')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12
plt.rcParams['hatch.linewidth'] = 3

# ?��린이 ?���? ?��?�� ?��?�� hatch ?��?��?�� ?��르게 ?��?��?�� 막�?? 그래?��
bars = plt.bar(df['�??���?'], df['?��린이?��고수'], facecolor='skyblue', edgecolor='black')

for i, bar in enumerate(bars):
    hatch_str = "/" * df['?��린이?��고수'].iloc[i]
    bar.set_hatch(hatch_str)

plt.title('?��린이 ?���? ?��?�� ?���? 막�?? 그래?��')
plt.xlabel('�??���?')
plt.ylabel('?��린이 ?���? ?��')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/jw/ndvxfvvs0j15nzphpj_wq_sr0000gn/T/ipykernel_52510/2147757650.py:38: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   plt.tight_layout()
# /var/folders/jw/ndvxfvvs0j15nzphpj_wq_sr0000gn/T/ipykernel_52510/2147757650.py:38: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from current font.
#   plt.tight_layout()
# /var/folders/jw/ndvxfvvs0j15nzphpj_wq_sr0000gn/T/ipykernel_52510/2147757650.py:38: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.tight_layout()
# /var/folders/jw/ndvxfvvs0j15nzphpj_wq_sr0000gn/T/ipykernel_52510/2147757650.py:38: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   plt.tight_layout()
# /var/folders/jw/ndvxfvvs0j15nzphpj_wq_sr0000gn/T/ipykernel_52510/2147757650.py:38: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   plt.tight_layout()
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
# plt.show()
plt.savefig('savefig_default.png')

# %%
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False  

# Pairplot -> 지역별로 어린이 사고 수 대비 어린이보호구역 CCTV 수'의 상관관계 분석
sns.pairplot(df, vars=['어린이사고수', '어린이보호구역CCTV수'], hue='지역구', palette='Set2')
plt.suptitLe('어린이 사고 수 대비 어린이보호구역 CCTV 수', y=1.02)
plt.show()
plt.title('Graph Title')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sophie/Desktop/230125_11AM/Weather-and-traffic-accidents/csy/csy_서울시_어린이_교통사고/서울_어린이_교통사고/Seoul_predict3_ex.ipynb 셀 19 line 3
#       <a href='vscode-notebook-cell:/Users/sophie/Desktop/230125_11AM/Weather-and-traffic-accidents/csy/csy_%EC%84%9C%EC%9A%B8%EC%8B%9C_%EC%96%B4%EB%A6%B0%EC%9D%B4_%EA%B5%90%ED%86%B5%EC%82%AC%EA%B3%A0/%EC%84%9C%EC%9A%B8_%EC%96%B4%EB%A6%B0%EC%9D%B4_%EA%B5%90%ED%86%B5%EC%82%AC%EA%B3%A0/Seoul_predict3_ex.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> from matplotlib import rc
# ...
