# %% [markdown]
# # 예측 vs 실제

# %% [markdown]
# # 실제

# %% [markdown]
# 1 양천구 / 2 강남구 / 3 송파구

# %%
# 실제
# 1=양천구 ,2=강남구, 3=송파구

import matplotlib.pyplot as plt

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = [1, 2, 3]
y = [4, 5, 6]

fig, ax = plt.subplots()

bars = ax.bar(x, y, color='lightgray', edgecolor='black')
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 예측 (선형회귀)

# %%
# 예측 = yello

# 1=은평구, 2=구로구, 3=강서구

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([100, 100, 100])

fig, ax = plt.subplots()

# 진한 노란색
bars = ax.bar(x, y, color='#FFD700', edgecolor='black')  
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 예측 ( 트리 )

# %%
# 예측 = yello

# 1=금천구40, 2=마포구60, 3=서초구80

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([40, 60, 80])

fig, ax = plt.subplots()

# 진한 노란색
bars = ax.bar(x, y, color='#FFFF99', edgecolor='black')  
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 예측 ( predictions )

# %%
# 예측 = yello

# 1=성동구60, 2=성북구80, 3=은평구100

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([60, 80, 100])

fig, ax = plt.subplots()

# 진한 노란색
bars = ax.bar(x, y, color='#FFD700', edgecolor='black')  
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 예측 ( 그래디언트 )

# %% [markdown]
# 어린이 사고 - 예측

# %%
# 예측 = yello

# 1=성동구40, 2=관악구60, 3=서초구80

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([40, 60, 80])

fig, ax = plt.subplots()

# 진한 노란색
bars = ax.bar(x, y, color='#FFD700', edgecolor='black')  
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 예측 1

# %% [markdown]
# 어린이 사고 - 예측

# %%
# 예측 = yello

# 1=은평구 ,2=강남구, 3=강동구

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

fig, ax = plt.subplots()

# 진한 노란색
bars = ax.bar(x, y, color='#FFD700', edgecolor='black')  
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 예측 2

# %% [markdown]
# 1 은평구 / 2 강남구 / 3 양천구

# %%
# 예측 2 

# 1=은평구 ,2=강남구, 3=양천구

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

fig, ax = plt.subplots()

# 진한 노란색
bars = ax.bar(x, y, color='#FFD700', edgecolor='black')  
bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 예측 3

# %% [markdown]
# 1 중구 / 2 서대문구 / 3 동작구

# %%
# 예측 3

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

fig, ax = plt.subplots()

# 연한 노란색
bars = ax.bar(x, y, color='#FFFF99', edgecolor='black')  

bars[0].set_hatch('x')
bars[1].set_hatch('O')
bars[2].set_hatch('.')

plt.tight_layout()
plt.show()
