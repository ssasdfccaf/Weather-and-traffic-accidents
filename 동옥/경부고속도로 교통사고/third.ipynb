# %%
# !pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in c:\python\python310\lib\site-packages (2.1.4)
# Requirement already satisfied: matplotlib in c:\python\python310\lib\site-packages (3.8.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\python\python310\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ogi\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python\python310\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\python310\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\python310\lib\site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ogi\appdata\roaming\python\python310\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\python\python310\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python\python310\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\ogi\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # 한글 폰트 경로 (Windows 기준)
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# CSV 파일 경로
file_path = '경부고속도로_전체_accidentInfoList.csv'

# CSV 파일 읽기 (encoding 지정)
df = pd.read_csv(file_path, delimiter=',', encoding='cp949')

# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# '월' 컬럼 추가
df['월'] = df['사고일시'].dt.month

# 월별 사고 수 계산
monthly_accidents = df.groupby('월').size()

# 막대 그래프 그리기
plt.figure(figsize=(10, 6))
monthly_accidents.plot(kind='bar', color='skyblue')
plt.title('월별 사고 수')
plt.xlabel('월')
plt.ylabel('사고 수')
plt.xticks(rotation=0)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc


# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # 한글 폰트 경로 (Windows 기준)
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# CSV 파일 경로
file_path = '경부고속도로_전체_accidentInfoList.csv'

# CSV 파일 읽기 (encoding 지정)
df = pd.read_csv(file_path, delimiter=',', encoding='cp949')

# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# 연도, 월, 일, 시간 컬럼 추가
df['연도'] = df['사고일시'].dt.year
df['월'] = df['사고일시'].dt.month
df['일'] = df['사고일시'].dt.day
df['시간'] = df['사고일시'].dt.hour

# 연도, 월, 일, 시간별 사고 수 계산
top_10_accidents = df.groupby(['연도', '월', '일', '시간']).size().sort_values(ascending=False).head(10)

# 막대 그래프 그리기
plt.figure(figsize=(12, 6))
top_10_accidents.plot(kind='bar', color='skyblue')
plt.title('Top 10 연도/월/일/시간별 사고 수')
plt.xlabel('연도/월/일/시간')
plt.ylabel('사고 수')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# '월', '일' 컬럼 추가
df['월'] = df['사고일시'].dt.month
df['일'] = df['사고일시'].dt.day

# 8월 16일에 발생한 사고만 조회
aug_16_accidents = df[(df['월'] == 8) & (df['일'] == 16)]

# 결과 출력
print(aug_16_accidents)
# Out:
#                  사고번호                사고일시   요일               시군구  사고내용  사망자수  \
# 482  2022081600100286 2022-08-16 14:00:00  화요일       경기도 안성시 원곡면  경상사고     0
# 483  2022081600100289 2022-08-16 14:00:00  화요일  충청북도 청주시 서원구 남이면  경상사고     0
# 484  2022081600100291 2022-08-16 14:00:00  화요일  충청남도 천안시 서북구 성거읍  경상사고     0
# 485  2022081600100317 2022-08-16 15:00:00  화요일   경기도 용인시 수지구 죽전동  경상사고     0
#
#      중상자수  경상자수  부상신고자수        사고유형  ... 가해운전자 연령 가해운전자 상해정도 피해운전자 차종  \
# 482     0     1       0    차대차 - 추돌  ...      36세       상해없음       승용
# 483     0     1       0    차대차 - 추돌  ...      44세       상해없음       특수
# 484     0    12       0    차대차 - 추돌  ...      30세       기타불명       승용
# 485     0     1       0  차대차 - 측면충돌  ...      48세       상해없음       승용
#
#     피해운전자 성별 피해운전자 연령 피해운전자 상해정도    연도  월   일  시간
# 482        여      64세         경상  2022  8  16  14
# 483        남      45세         경상  2022  8  16  14
# 484        남      69세       상해없음  2022  8  16  14
# 485        남      66세         경상  2022  8  16  15
#
# [4 rows x 26 columns]

# %%
# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# '시간대' 컬럼 추가
df['시간대'] = df['사고일시'].dt.hour

# 시간대별 사고량 계산
시간대별_사고수 = df['시간대'].value_counts().sort_index()

# 막대그래프 그리기
plt.figure(figsize=(10, 6))
시간대별_사고수.plot(kind='bar', color='skyblue')
plt.title('시간대별 사고량')
plt.xlabel('시간대')
plt.ylabel('사고량')
plt.show()

# %%
# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# '요일' 컬럼을 기준으로 그룹화하여 사고 수 계산
요일별_사고수 = df['요일'].value_counts().sort_index()

# 막대그래프 그리기
plt.figure(figsize=(10, 6))
요일별_사고수.plot(kind='bar', color='skyblue')
plt.title('요일별 사고량')
plt.xlabel('요일')
plt.ylabel('사고량')
plt.show()

# %%
# '시군구' 컬럼에서 첫번째 영역 추출하여 새로운 컬럼 생성
df['지역'] = df['시군구'].apply(lambda x: x.split()[0])

# '지역' 컬럼을 기준으로 그룹화하여 사고 수 계산
지역별_사고수 = df['지역'].value_counts().sort_index()

# 막대그래프 그리기
plt.figure(figsize=(10, 6))
지역별_사고수.plot(kind='bar', color='lightcoral')
plt.title('지역별 사고량')
plt.xlabel('지역')
plt.ylabel('사고량')
plt.show()

# %%
# 피해운전자 연령대 레이블 생성
df['피해자_연령대'] = df['피해운전자 연령'].apply(lambda x: int(x[:-1]) if pd.notna(x) and x[-1] == '세' else None)

# '피해자_연령대' 컬럼을 기준으로 그룹화하여 사고 수 계산
연령대별_사고수 = df['피해자_연령대'].value_counts().sort_index()

# 막대그래프 그리기
plt.figure(figsize=(10, 6))
연령대별_사고수.plot(kind='bar', color='skyblue')
plt.title('연령대별 사고량')
plt.xlabel('연령대')
plt.ylabel('사고량')
plt.show()

# %%
# 가해자 연령대 레이블 생성
df['피해자_연령'] = df['피해운전자 연령'].apply(lambda x: int(x[:-1]) if x[-1] == '세' else 0)  # 세 제거 후 정수 변환
피해자_연령대 = pd.cut(df['피해자_연령'], bins=[0, 19, 29, 39, 49, 59, 69, 130], labels=['10대 이하', '20대', '30대', '40대', '50대', '60대', '70대 이상'], right=False)

# 가해자 연령대별 사고 수 계산
피해자_연령대별_사고수 = 피해자_연령대.value_counts().sort_index()

# 막대그래프 그리기
plt.figure(figsize=(12, 6))
피해자_연령대별_사고수.plot(kind='bar', color='skyblue')
plt.title('피해자 연령대별 사고량')
plt.xlabel('피해자 연령대')
plt.ylabel('사고량')
plt.xticks(rotation=45, ha='right')  # X축 레이블 회전
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 가해자 연령대 레이블 생성
# ----> 2 df['피해자_연령'] = df['피해운전자 연령'].apply(lambda x: int(x[:-1]) if x[-1] == '세' else 0)  # 세 제거 후 정수 변환
#       3 피해자_연령대 = pd.cut(df['피해자_연령'], bins=[0, 19, 29, 39, 49, 59, 69, 130], labels=['10대 이하', '20대', '30대', '40대', '50대', '60대', '70대 이상'], right=False)
#       5 # 가해자 연령대별 사고 수 계산
#
# NameError: name 'df' is not defined

# %%
# 가해자 연령대 레이블 생성
df['가해자_연령'] = df['가해운전자 연령'].apply(lambda x: int(x[:-1]) if x[-1] == '세' else 0)  # 세 제거 후 정수 변환
가해자_연령대 = pd.cut(df['가해자_연령'], bins=[0, 19, 29, 39, 49, 59, 69, 130], labels=['10대 이하', '20대', '30대', '40대', '50대', '60대', '70대 이상'], right=False)

# 가해자 연령대별 사고 수 계산
가해자_연령대별_사고수 = 가해자_연령대.value_counts().sort_index()

# 막대그래프 그리기
plt.figure(figsize=(12, 6))
가해자_연령대별_사고수.plot(kind='bar', color='skyblue')
plt.title('가해자 연령대별 사고량')
plt.xlabel('가해자 연령대')
plt.ylabel('사고량')
plt.xticks(rotation=45, ha='right')  # X축 레이블 회전
plt.show()

# %%
# 법규위반별 사고 수 계산
법규위반별_사고수 = df['법규위반'].value_counts()

# 막대그래프 그리기
plt.figure(figsize=(12, 6))
법규위반별_사고수.plot(kind='bar', color='coral')
plt.title('법규위반별 사고량')
plt.xlabel('법규위반')
plt.ylabel('사고량')
plt.xticks(rotation=45, ha='right')  # X축 레이블 회전
plt.show()

# %%
# 사고유형별 사고 수 계산
사고유형별_사고수 = df['사고유형'].value_counts()

# 막대그래프 그리기
plt.figure(figsize=(12, 6))
사고유형별_사고수.plot(kind='bar', color='skyblue')
plt.title('사고유형별 사고량')
plt.xlabel('사고유형')
plt.ylabel('사고량')
plt.xticks(rotation=45, ha='right')  # X축 레이블 회전
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # 한글 폰트 경로 (Windows 기준)
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# CSV 파일 경로
file_path = './경부고속도로_전체_accidentInfoList.csv'

# CSV 파일 읽기
df = pd.read_csv(file_path, delimiter=',', encoding='CP949')

# 사고유형과 법규위반의 교차표 생성
cross_table = pd.crosstab(df['사고유형'], df['법규위반'])

# 히트맵 그리기
plt.figure(figsize=(15, 8))
sns.heatmap(cross_table, annot=True, fmt='d', cmap='YlGnBu', cbar=False)
plt.title('사고유형과 법규위반의 상관관계')
plt.xlabel('법규위반')
plt.ylabel('사고유형')
plt.show()

# %%
cross_table = pd.crosstab(df['사고유형'], df['법규위반'])
sns.heatmap(cross_table, annot=True, cmap='YlGnBu', fmt="d")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# '월' 컬럼 추가
df['월'] = df['사고일시'].dt.month



# 피해자 연령대 레이블 생성
df['피해자_연령'] = df['피해운전자 연령'].apply(lambda x: int(x[:-1]) if x[-1] == '세' else 0)  # 세 제거 후 정수 변환
df['피해자_연령대'] = pd.cut(df['피해자_연령'], bins=[0, 19, 29, 39, 49, 59, 69, 130], labels=['10대 미만', '20대', '30대', '40대', '50대', '60대', '70대 이상'], right=False)

# 지역 및 월별 사고수를 계산
pivot_table = df.pivot_table(index='피해자_연령대', columns='월', values='사고번호', aggfunc='count', fill_value=0)

# 히트맵 생성
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, cmap='YlGnBu', annot=True, fmt="d")
plt.title('나이대별 월별 사고 히트맵')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

# 데이터 불러오기
df = pd.read_csv(file_path, delimiter=',', encoding='cp949')

# 안전거리 미확보와 측면충돌에 해당하는 데이터 추출
subset_df = df[df['법규위반'].isin(['안전거리미확보', '측면충돌'])]

# 교차표 생성
contingency_table = pd.crosstab(subset_df['법규위반'], subset_df['사고유형'])

# 카이제곱 검정
chi2, p, _, _ = chi2_contingency(contingency_table)

# 시각화
plt.figure(figsize=(10, 6))
sns.heatmap(contingency_table, annot=True, fmt='d', cmap='Blues')
plt.title('안전거리 미확보와 측면충돌 간의 교차표')
plt.show()

# 카이제곱 검정 결과 출력
print(f"Chi-squared: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-squared: 0.0
# P-value: 1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 불러오기
file_path = './경부고속도로_전체_accidentInfoList.csv'
df = pd.read_csv(file_path, delimiter=',', encoding='cp949')

# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# '월' 컬럼 추가
df['월'] = df['사고일시'].dt.month

# '월'과 '사고유형'으로 필터링하여 데이터프레임 생성
monthly_accidents = df[df['사고유형'] == '차대차 - 측면충돌'].groupby('월').size().reset_index(name='측면충돌사고수')

# 막대 그래프 시각화
plt.figure(figsize=(10, 6))
sns.barplot(x='월', y='측면충돌사고수', data=monthly_accidents, palette='viridis')
plt.title('월별 측면충돌사고 수')
plt.xlabel('월')
plt.ylabel('사고 수')
plt.show()
# Out:
# C:\Users\ogi\AppData\Local\Temp\ipykernel_8520\1881330359.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='월', y='측면충돌사고수', data=monthly_accidents, palette='viridis')

# %%
# '도로형태'와 '사고유형'으로 필터링하여 교차표 생성
cross_table = pd.crosstab(df['노면상태'], df['사고유형'])

# 히트맵 시각화
plt.figure(figsize=(12, 8))
sns.heatmap(cross_table, annot=True, fmt='d', cmap='YlGnBu')
plt.title('노면상태와 사고유형 간의 히트맵')
plt.xlabel('노면상태')
plt.ylabel('도로형태')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# 데이터 불러오기
file_path = './경부고속도로_전체_accidentInfoList.csv'
df = pd.read_csv(file_path, delimiter=',', encoding='cp949')

# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# 15시에 일어난 사고만 필터링
df_15시 = df[df['사고일시'].dt.hour == 15]

# 15시에 일어난 사고 중 법규위반의 빈도수 계산
법규위반_빈도 = df_15시['법규위반'].value_counts()

# 막대그래프 시각화
plt.figure(figsize=(12, 6))
법규위반_빈도.plot(kind='bar', color='skyblue')
plt.title('15시에 발생한 사고 중 법규위반별 빈도')
plt.xlabel('법규위반')
plt.ylabel('빈도')
plt.show()
# Out:
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49373 (\N{HANGUL SYLLABLE SAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48277 (\N{HANGUL SYLLABLE BEOB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44508 (\N{HANGUL SYLLABLE GYU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50504 (\N{HANGUL SYLLABLE AN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48520 (\N{HANGUL SYLLABLE BUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44144 (\N{HANGUL SYLLABLE GEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49888 (\N{HANGUL SYLLABLE SIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ogi\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 데이터 불러오기
file_path = './경부고속도로_전체_accidentInfoList.csv'
df = pd.read_csv(file_path, delimiter=',', encoding='cp949')

# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# 시간과 지역 추출
df['시간'] = df['사고일시'].dt.hour
df['지역'] = df['시군구'].str.split(' ').str[0]

# 지역에 대한 교통사고량 계산
heatmap_data = df.groupby(['지역', '시간']).size().unstack(fill_value=0)

# 히트맵 시각화
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)
plt.title('지역 및 시간별 교통사고량 히트맵')
plt.xlabel('시간')
plt.ylabel('지역')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 데이터 불러오기
file_path = './경부고속도로_전체_accidentInfoList.csv'
df = pd.read_csv(file_path, delimiter=',', encoding='cp949')

# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# 선택할 구 리스트
selected_gu_list = ['수원시', '성남시', '용인시', '안양시', '부천시', '안산시', '고양시', '용인시']

# 각 구에 해당하는 데이터프레임 생성
dfs_by_gu = {gu: df[df['시군구'].str.contains(gu)] for gu in selected_gu_list}

# 히트맵 시각화
fig, ax = plt.subplots(figsize=(12, 8))

heatmap_data = pd.DataFrame({gu: df_gu.groupby(df_gu['사고일시'].dt.hour).size() for gu, df_gu in dfs_by_gu.items()})

sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)
plt.title('경기도 특정 구 및 시간별 교통사고량 히트맵')
plt.xlabel('시간')
plt.ylabel('지역')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 26
#      22 fig, ax = plt.subplots(figsize=(12, 8))
#      24 heatmap_data = pd.DataFrame({gu: df_gu.groupby(df_gu['사고일시'].dt.hour).size() for gu, df_gu in dfs_by_gu.items()})
# ---> 26 sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)
#      27 plt.title('경기도 특정 구 및 시간별 교통사고량 히트맵')
#      28 plt.xlabel('시간')
#
# File c:\Python\Python312\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File c:\Python\Python312\Lib\site-packages\seaborn\matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File c:\Python\Python312\Lib\site-packages\seaborn\matrix.py:260, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     258 lum = relative_luminance(color)
#     259 text_color = ".15" if lum > .408 else "w"
# --> 260 annotation = ("{:" + self.fmt + "}").format(val)
#     261 text_kwargs = dict(color=text_color, ha="center", va="center")
#     262 text_kwargs.update(self.annot_kws)
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %%
# '시군구' 컬럼에서 첫번째 영역 추출하여 새로운 컬럼 생성
df['지역'] = df['시군구'].apply(lambda x: x.split()[0])

# 선택할 구 리스트
selected_gu_list = ['서울특별시', '성남시', '용인시', '부산광역시', '대구광역시', '대전광역시', '울산광역시']

# 각 구에 해당하는 데이터프레임 생성
dfs_by_gu = {gu: df[df['시군구'].str.contains(gu)] for gu in selected_gu_list}

# 지역별 사고량 막대그래프 그리기
plt.figure(figsize=(10, 6))
for gu, df_gu in dfs_by_gu.items():
    plt.bar(gu, df_gu.shape[0], color='lightcoral')

plt.title('지역별 사고량')
plt.xlabel('지역')
plt.ylabel('사고량')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 데이터 불러오기
file_path = './경부고속도로_전체_accidentInfoList.csv'
df = pd.read_csv(file_path, delimiter=',', encoding='cp949')

# '사고일시' 컬럼을 datetime 형식으로 변환
df['사고일시'] = pd.to_datetime(df['사고일시'], format='%Y년 %m월 %d일 %H시')

# 선택할 구 리스트
selected_gu_list = ['서울특별시', '성남시', '용인시', '부산광역시', '대구광역시', '대전광역시', '울산광역시']

# 각 구에 해당하는 데이터프레임 생성
dfs_by_gu = {gu: df[df['시군구'].str.contains(gu)] for gu in selected_gu_list}

# 히트맵 시각화
fig, ax = plt.subplots(figsize=(12, 8))

heatmap_data = pd.DataFrame({gu: df_gu.groupby(df_gu['사고일시'].dt.hour).size() for gu, df_gu in dfs_by_gu.items()})

sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)
plt.title('경기도 특정 구 및 시간별 교통사고량 히트맵')
plt.xlabel('시간')
plt.ylabel('지역')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 26
#      22 fig, ax = plt.subplots(figsize=(12, 8))
#      24 heatmap_data = pd.DataFrame({gu: df_gu.groupby(df_gu['사고일시'].dt.hour).size() for gu, df_gu in dfs_by_gu.items()})
# ---> 26 sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)
#      27 plt.title('경기도 특정 구 및 시간별 교통사고량 히트맵')
#      28 plt.xlabel('시간')
#
# File c:\Python\Python312\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File c:\Python\Python312\Lib\site-packages\seaborn\matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File c:\Python\Python312\Lib\site-packages\seaborn\matrix.py:260, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     258 lum = relative_luminance(color)
#     259 text_color = ".15" if lum > .408 else "w"
# --> 260 annotation = ("{:" + self.fmt + "}").format(val)
#     261 text_kwargs = dict(color=text_color, ha="center", va="center")
#     262 text_kwargs.update(self.annot_kws)
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %%
import pandas as pd
import matplotlib.pyplot as plt


# '시군구' 컬럼을 띄어쓰기를 기준으로 분할하고 필요한 부분 선택
df['분류된지역'] = df['시군구'].apply(lambda x: ' '.join(x.split()[:4]))

# 지역별 사고 수 계산
accident_counts = df['분류된지역'].value_counts()

# 상위 10개 지역 선택
top10_accident_counts = accident_counts.head(10)

# 상위 10개 지역별 사고 수 막대그래프 그리기
plt.figure(figsize=(15, 6))
top10_accident_counts.plot(kind='bar', color='lightcoral')
plt.title('상위 10개 지역별 사고량')
plt.xlabel('지역')
plt.ylabel('사고 수')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# '시군구' 컬럼을 띄어쓰기를 기준으로 분할하고 필요한 부분 선택
df['분류된지역'] = df['시군구'].apply(lambda x: ' '.join(x.split()[:4]))

# top10 지역 선택
top10_areas = df['분류된지역'].value_counts().head(10).index
df_top10 = df[df['분류된지역'].isin(top10_areas)]

# '사고일시' 컬럼을 datetime 형식으로 변환
df_top10['사고일시'] = pd.to_datetime(df_top10['사고일시'], format='%Y년 %m월 %d일 %H시')

# '시간대' 컬럼 추가
df_top10['시간대'] = df_top10['사고일시'].dt.hour

# top10 지역의 시간대별 사고수 히트맵 시각화
plt.figure(figsize=(12, 8))
heatmap_data = pd.pivot_table(df_top10, values='사고번호', index='분류된지역', columns='시간대', aggfunc='count', fill_value=0)

sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)
plt.title('Top 10 지역 시간대별 사고수 히트맵')
plt.xlabel('시간대')
plt.ylabel('지역')
plt.show()
# Out:
# C:\Users\ogi\AppData\Local\Temp\ipykernel_15056\93047919.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top10['사고일시'] = pd.to_datetime(df_top10['사고일시'], format='%Y년 %m월 %d일 %H시')
# C:\Users\ogi\AppData\Local\Temp\ipykernel_15056\93047919.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top10['시간대'] = df_top10['사고일시'].dt.hour

# %%
# '시군구' 컬럼을 띄어쓰기를 기준으로 분할하고 필요한 부분 선택
df['분류된지역'] = df['시군구'].apply(lambda x: ' '.join(x.split()[:4]))

# 15시에 발생한 사고만 필터링
df_15_hour = df[df['사고일시'].dt.hour == 15]

# 15시에 발생한 사고 중 top 10 지역 선택
top10_areas_15_hour = df_15_hour['분류된지역'].value_counts().head(10).index
df_top10_15_hour = df_15_hour[df_15_hour['분류된지역'].isin(top10_areas_15_hour)]

print(df_top10_15_hour)
# Out:
#                  사고번호                사고일시   요일              시군구    사고내용  사망자수  \
# 32   2022011400100327 2022-01-14 15:00:00  금요일  경기도 용인시 기흥구 보정동    경상사고     0
# 67   2022012600100308 2022-01-26 15:00:00  수요일    서울특별시 서초구 원지동    경상사고     0
# 81   2022020300100259 2022-02-03 15:00:00  목요일      경기도 오산시 부산동    경상사고     0
# 89   2022020800100266 2022-02-08 15:00:00  화요일  경기도 용인시 기흥구 고매동    중상사고     0
# 147  2022031300100158 2022-03-13 15:00:00  일요일       경기도 오산시 원동    경상사고     0
# 156  2022032000100143 2022-03-20 15:00:00  일요일  경기도 성남시 분당구 금곡동    중상사고     0
# 181  2022040300100201 2022-04-03 15:00:00  일요일      경기도 평택시 진위면    경상사고     0
# 205  2022041200100305 2022-04-12 15:00:00  화요일  경기도 용인시 기흥구 고매동    경상사고     0
# 263  2022050900100356 2022-05-09 15:00:00  월요일      경기도 평택시 진위면    경상사고     0
# 294  2022052400100345 2022-05-24 15:00:00  화요일  경기도 용인시 기흥구 신갈동    경상사고     0
# 379  2022070600100314 2022-07-06 15:00:00  수요일      경기도 오산시 부산동    경상사고     0
# 401  2022071300100289 2022-07-13 15:00:00  수요일  경기도 용인시 수지구 죽전동    경상사고     0
# 414  2022071700100233 2022-07-17 15:00:00  일요일  경기도 용인시 수지구 죽전동    경상사고     0
# 449  2022073100100240 2022-07-31 15:00:00  일요일  경기도 용인시 기흥구 고매동    중상사고     0
# 485  2022081600100317 2022-08-16 15:00:00  화요일  경기도 용인시 수지구 죽전동    경상사고     0
# 497  2022082300100329 2022-08-23 15:00:00  화요일      경기도 화성시 방교동    경상사고     0
# 504  2022082600100327 2022-08-26 15:00:00  금요일  경기도 용인시 기흥구 보정동    경상사고     0
# 522  2022083000100328 2022-08-30 15:00:00  화요일  경기도 용인시 기흥구 고매동    경상사고     0
# 543  2022090800100411 2022-09-08 15:00:00  목요일    서울특별시 서초구 원지동  부상신고사고     0
# 565  2022091900100294 2022-09-19 15:00:00  월요일      경기도 화성시 방교동    경상사고     0
# 583  2022092700100319 2022-09-27 15:00:00  화요일      경기도 평택시 진위면    중상사고     0
# 600  2022100700100393 2022-10-07 15:00:00  금요일       경기도 오산시 원동    경상사고     0
# 723  2022111900100313 2022-11-19 15:00:00  토요일    서울특별시 서초구 원지동    경상사고     0
# 724  2022112000100232 2022-11-20 15:00:00  일요일    서울특별시 서초구 원지동    경상사고     0
# 725  2022112000100233 2022-11-20 15:00:00  일요일  경기도 용인시 기흥구 신갈동    경상사고     0
# 789  2022121400100370 2022-12-14 15:00:00  수요일       경기도 오산시 원동    경상사고     0
# 810  2022122200100284 2022-12-22 15:00:00  목요일       경기도 오산시 원동    경상사고     0
# 823  2022122800100324 2022-12-28 15:00:00  수요일  경기도 성남시 분당구 금곡동  부상신고사고     0
#
#      중상자수  경상자수  부상신고자수        사고유형  ... 가해운전자 차종 가해운전자 성별 가해운전자 연령  \
# 32      0     1       0    차대차 - 기타  ...       승합        남      61세
# 67      0     1       0    차대차 - 기타  ...       승용        남      55세
# 81      0     3       0    차대차 - 추돌  ...       승용        남      38세
# 89      1     2       0  차대차 - 측면충돌  ...       화물        남      58세
# 147     0     3       0  차대차 - 측면충돌  ...       승용        남      24세
# 156     2     2       0    차대차 - 기타  ...       승용        남      35세
# 181     0     2       0    차대차 - 기타  ...       승합        남      33세
# 205     0     1       0    차대차 - 추돌  ...       승용        남      60세
# 263     0     2       0    차대차 - 기타  ...       승용        남      73세
# 294     0     2       2    차대차 - 추돌  ...       승용        남      60세
# 379     0     1       1    차대차 - 추돌  ...       화물        남      59세
# 401     0     6       0    차대차 - 추돌  ...       승용        남      66세
# 414     0    20       0    차대차 - 기타  ...       승합        남      54세
# 449     1     0       0    차대차 - 추돌  ...       승용        남      45세
# 485     0     1       0  차대차 - 측면충돌  ...       화물        남      48세
# 497     0     1       0    차대차 - 기타  ...       승용        남      62세
# 504     0     1       0    차대차 - 추돌  ...       승용        남      50세
# 522     0     2       0    차대차 - 기타  ...       승용        남      40세
# 543     0     0       1    차대차 - 추돌  ...       화물        남      30세
# 565     0     1       0    차대차 - 기타  ...       승용        여      48세
# 583     1    10       0    차대차 - 추돌  ...       화물        남      68세
# 600     0     3       0    차대차 - 기타  ...       화물        남      65세
# 723     0     1       0    차대차 - 추돌  ...       승용        남      29세
# 724     0     3       0    차대차 - 기타  ...       승용        남      55세
# 725     0     2       0    차대차 - 기타  ...       승용        남      39세
# 789     0     1       0    차대차 - 기타  ...       승용        남      75세
# 810     0     2       0    차대차 - 추돌  ...       승용        남      67세
# 823     0     0       1    차대차 - 기타  ...       승용        여      59세
#
#     가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도            분류된지역 시간대
# 32        상해없음       승용        남      41세         경상  경기도 용인시 기흥구 보정동  15
# 67        상해없음       승용        남      41세         경상    서울특별시 서초구 원지동  15
# 81        상해없음       승용        남      45세         경상      경기도 오산시 부산동  15
# 89        상해없음       승용        남      58세         경상  경기도 용인시 기흥구 고매동  15
# 147       상해없음       승용        남      38세         경상       경기도 오산시 원동  15
# 156       상해없음       승용        남      36세         경상  경기도 성남시 분당구 금곡동  15
# 181       상해없음       승합        남      52세         경상      경기도 평택시 진위면  15
# 205       상해없음       승용        여      39세         경상  경기도 용인시 기흥구 고매동  15
# 263       상해없음       승용        남      29세         경상      경기도 평택시 진위면  15
# 294       상해없음       승용        남      40세         경상  경기도 용인시 기흥구 신갈동  15
# 379       상해없음       화물        남      50세         경상      경기도 오산시 부산동  15
# 401       상해없음       승용        남      59세         경상  경기도 용인시 수지구 죽전동  15
# 414       상해없음       승합        남      41세       상해없음  경기도 용인시 수지구 죽전동  15
# 449       상해없음       승용        여      56세         중상  경기도 용인시 기흥구 고매동  15
# 485       상해없음       승용        남      66세         경상  경기도 용인시 수지구 죽전동  15
# 497       상해없음       승용        여      36세         경상      경기도 화성시 방교동  15
# 504       상해없음       승용        여      43세         경상  경기도 용인시 기흥구 보정동  15
# 522       상해없음       승합        남      59세         경상  경기도 용인시 기흥구 고매동  15
# 543       상해없음       승용        남      59세       부상신고    서울특별시 서초구 원지동  15
# 565       상해없음       화물        남      57세         경상      경기도 화성시 방교동  15
# 583       상해없음       화물        남      59세         중상      경기도 평택시 진위면  15
# 600       상해없음       승용        남      48세         경상       경기도 오산시 원동  15
# 723       상해없음       승용        여      34세         경상    서울특별시 서초구 원지동  15
# 724       상해없음       승용        남      40세         경상    서울특별시 서초구 원지동  15
# 725       상해없음       승용        남      39세         경상  경기도 용인시 기흥구 신갈동  15
# 789       상해없음       승용        남      34세       상해없음       경기도 오산시 원동  15
# 810       상해없음       승용        남      42세         경상       경기도 오산시 원동  15
# 823       상해없음       승합        남      52세       부상신고  경기도 성남시 분당구 금곡동  15
#
# [28 rows x 24 columns]

# %%
# '시군구' 컬럼을 띄어쓰기를 기준으로 분할하고 필요한 부분 선택
df['분류된지역'] = df['시군구'].apply(lambda x: ' '.join(x.split()[:4]))

# 15시에 발생한 사고만 필터링
df_15_hour = df[df['사고일시'].dt.hour == 15]

# top 10 지역 선택
top10_areas_15_hour = df_15_hour['분류된지역'].value_counts().head(10).index
df_top10_15_hour = df_15_hour[df_15_hour['분류된지역'].isin(top10_areas_15_hour)]

# top 10 지역별 사고 수 막대그래프 그리기
plt.figure(figsize=(15, 6))
df_top10_15_hour['분류된지역'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('15시에 발생한 Top 10 지역별 사고량')
plt.xlabel('지역')
plt.ylabel('사고 수')
plt.show()
